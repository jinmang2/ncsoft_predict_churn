# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Survival regression

# %%
from lifelines.datasets import load_rossi

rossi = load_rossi()
rossi.head()
# Out:
#    week  arrest  fin  age  race  wexp  mar  paro  prio
# 0    20       1    0   27     1     0    0     1     3
# 1    17       1    0   18     1     0    0     1     8
# 2    25       1    0   19     0     1    0     1    13
# 3    52       0    1   23     1     1    1     1     1
# 4    52       0    0   19     0     1    0     1     3

# %%
rossi.shape
# Out:
# (432, 9)

# %% [markdown]
# # Cox's proportional hazard model
# $$h\left(t|x\right)=b_0\left(t\right)exp\bigg(\sum_{i=1}^{n}{b_i\left(x_i-\bar{x_i}\right)}\bigg)$$

# %%
from lifelines import CoxPHFitter

cph = CoxPHFitter()
cph.fit(rossi, duration_col='week', event_col='arrest', show_progress=True)
cph.print_summary()
# Out:
# Iteration 5: norm_delta = 0.00000, step_size = 1.0000, ll = -658.74766, newton_decrement = 0.00000, seconds_since_start = 0.1Convergence completed after 5 iterations.
# <lifelines.CoxPHFitter: fitted with 432 observations, 318 censored>
#       duration col = 'week'
#          event col = 'arrest'
# number of subjects = 432
#   number of events = 114
# partial log-likelihood = -658.75
#   time fit was run = 2019-08-20 07:59:46 UTC
#
# ---
#       coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# fin  -0.38      0.68      0.19           -0.75           -0.00                0.47                1.00
# age  -0.06      0.94      0.02           -0.10           -0.01                0.90                0.99
# race  0.31      1.37      0.31           -0.29            0.92                0.75                2.50
# wexp -0.15      0.86      0.21           -0.57            0.27                0.57                1.30
# mar  -0.43      0.65      0.38           -1.18            0.31                0.31                1.37
# paro -0.08      0.92      0.20           -0.47            0.30                0.63                1.35
# prio  0.09      1.10      0.03            0.04            0.15                1.04                1.16
#
#          z      p  -log2(p)
# fin  -1.98   0.05      4.40
# age  -2.61   0.01      6.79
# race  1.02   0.31      1.70
# wexp -0.71   0.48      1.06
# mar  -1.14   0.26      1.97
# paro -0.43   0.66      0.59
# prio  3.19 <0.005      9.48
# ---
# Concordance = 0.64
# Log-likelihood ratio test = 33.27 on 7 df, -log2(p)=15.37

# %%
cph.predict_partial_hazard(rossi).values.ravel()
# Out:
# array([1.21912632, 3.23025008, 3.03105799, 0.48771188, 1.21402458,
#        1.23865487, 0.57985289, 1.1107552 , 2.32724581, 1.29794575,
#        0.8835124 , 0.4941195 , 2.23828594, 0.58703863, 1.82248085,
#        0.8733737 , 3.0297976 , 1.81044501, 3.11579294, 0.75862937,
#        1.68098936, 0.13322443, 0.58423268, 0.4125429 , 0.83855334,
#        1.03761154, 0.61922794, 1.91747731, 1.32076914, 1.01404388,
#        1.04965683, 1.09990091, 0.2510082 , 0.85023702, 1.35733482,
#        0.97969276, 1.67954286, 1.04259498, 1.57551533, 0.9909423 ,
#        0.6215368 , 1.03837589, 4.70783812, 1.48264271, 1.20528635,
#        1.10436999, 3.62820145, 1.08508871, 0.46577579, 0.54576073,
#        0.35428868, 0.79700938, 0.44876036, 2.34848207, 0.53483499,
#        0.62632953, 0.40132419, 1.07527674, 0.8158617 , 0.57189723,
# 50.0  0.725969  0.428038  0.451031  0.879752  0.726942  0.722254  0.858714
#
#            7         8         9    ...       422       423       424  \
# 5.0   0.989139  0.977378  0.987320  ...  0.989129  0.980101  0.980231
# 25.0  0.886104  0.776194  0.868229  ...  0.886011  0.800471  0.801649
# 50.0  0.746932  0.542625  0.711092  ...  0.746745  0.584487  0.586563
#
#            425       426       427       428       429       430       431
# 5.0   0.988875  0.994450  0.995909  0.985189  0.994319  0.990843  0.993039
# 25.0  0.883492  0.940239  0.955622  0.847704  0.938870  0.903159  0.925566
# 50.0  0.741632  0.861836  0.896252  0.671203  0.858810  0.782096  0.829740
#
# [3 rows x 432 columns]

# %%
cph.predict_median(rossi)
# Out:
#       0.5
# 0     inf
# 1    44.0
# 2    46.0
# 3     inf
# 4     inf
# 5     inf
# 6     inf
# 7     inf
# 8     inf
# 9     inf
# 10    inf
# 11    inf
# 12    inf
# 13    inf
# 14    inf
# 15    inf
# 16   46.0
# 17    inf
# 18   46.0
# 19    inf
# 20    inf
# 21    inf
# 22    inf
# 23    inf
# 24    inf
# 25    inf
# 26    inf
# 27    inf
# 28    inf
# 29    inf
# ..    ...
# 402   inf
# 403   inf
# 404   inf
# 405   inf
# 406   inf
# 407   inf
# 408   inf
# 409   inf
# 410   inf
# 411   inf
# 412   inf
# 413   inf
# 414   inf
# 415   inf
# 416   inf
# 417   inf
# 418   inf
# 419   inf
# 420   inf
# 421   inf
# 422   inf
# 423   inf
# 424   inf
# 425   inf
# 426   inf
# 427   inf
# 428   inf
# 429   inf
# 430   inf
# 431   inf
#
# [432 rows x 1 columns]

# %%
import lifelines
lifelines.__version__
# Out:
# '0.22.3'

# %%
rossi = load_rossi()
censored_subjects = rossi.loc[~rossi['arrest'].astype(bool)] # 발현 X
censored_subjects_last_obs = censored_subjects['week']

# %%
cph.predict_partial_hazard(censored_subjects, conditional_after=censored_subjects_last_obs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-03c3744a2b51> in <module>
# ----> 1 cph.predict_partial_hazard(censored_subjects, conditional_after=censored_subjects_last_obs)
#
# TypeError: predict_partial_hazard() got an unexpected keyword argument 'conditional_after'

# %%
cph.predict_survival_function(censored_subjects, times=[5., 25., 50.], conditional_after=censored_subjects_last_obs)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-29-0a166cbc60a1> in <module>
# ----> 1 cph.predict_survival_function(censored_subjects, times=[5., 25., 50.], conditional_after=censored_subjects_last_obs)
#
# ~\Anaconda3\envs\keras\lib\site-packages\lifelines\fitters\coxph_fitter.py in predict_survival_function(self, X, times, conditional_after)
#    1527             the survival probabilities of individuals over the timeline
#    1528         """
# -> 1529         return np.exp(-self.predict_cumulative_hazard(X, times=times, conditional_after=conditional_after))
#    1530
#    1531     def predict_percentile(self, X, p=0.5, conditional_after=None):
#
# ~\Anaconda3\envs\keras\lib\site-packages\lifelines\fitters\coxph_fitter.py in predict_cumulative_hazard(self, X, times, conditional_after)
#    1465         """
#    1466         if conditional_after is not None:
# -> 1467             raise NotImplementedError("Sorry, conditional_after for Cox is tricky to do. It's not implemented yet.")
#    1468
#    1469         if self.strata:
#
# NotImplementedError: Sorry, conditional_after for Cox is tricky to do. It's not implemented yet.

# %%
cph.predict_median(censored_subjects, conditional_after=censored_subjects_last_obs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-04cc3c8631cd> in <module>
# ----> 1 cph.predict_median(censored_subjects, conditional_after=censored_subjects_last_obs)
#
# TypeError: predict_median() got an unexpected keyword argument 'conditional_after'

# %%
from lifelines.datasets import load_rossi
from lifelines import CoxPHFitter

rossi_dataset = load_rossi()
cph = CoxPHFitter()
cph.fit(rossi_dataset, duration_col='week', event_col='arrest', show_progress=True)

cph.plot()
# Out:
# Iteration 5: norm_delta = 0.00000, step_size = 1.0000, ll = -658.74766, newton_decrement = 0.00000, seconds_since_start = 0.0Convergence completed after 5 iterations.

# %%
from lifelines.datasets import load_rossi
from lifelines import CoxPHFitter

rossi_dataset = load_rossi()
cph = CoxPHFitter()
cph.fit(rossi_dataset, duration_col='week', event_col='arrest', show_progress=True)

cph.plot_covariate_groups('prio', [0, 2, 4, 6, 8, 10], cmap='coolwarm')
# Out:
# Iteration 5: norm_delta = 0.00000, step_size = 1.0000, ll = -658.74766, newton_decrement = 0.00000, seconds_since_start = 0.1Convergence completed after 5 iterations.

# %%
from lifelines.datasets import load_rossi
from lifelines import CoxPHFitter

rossi_dataset = load_rossi()
cph = CoxPHFitter()
cph.fit(rossi_dataset, 'week', event_col='arrest', strata=['race'], show_progress=True)

cph.print_summary()  # access the results using cph.summary
# Out:
# Iteration 5: norm_delta = 0.00000, step_size = 1.0000, ll = -620.56361, newton_decrement = 0.00000, seconds_since_start = 0.1Convergence completed after 5 iterations.
# <lifelines.CoxPHFitter: fitted with 432 observations, 318 censored>
#       duration col = 'week'
#          event col = 'arrest'
#             strata = ['race']
# number of subjects = 432
#   number of events = 114
# partial log-likelihood = -620.56
#   time fit was run = 2019-08-20 12:44:53 UTC
#
# ---
#       coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# fin  -0.38      0.68      0.19           -0.75           -0.00                0.47                1.00
# age  -0.06      0.94      0.02           -0.10           -0.01                0.90                0.99
# wexp -0.14      0.87      0.21           -0.56            0.27                0.57                1.32
# mar  -0.44      0.64      0.38           -1.19            0.31                0.30                1.36
# paro -0.09      0.92      0.20           -0.47            0.30                0.63                1.35
# prio  0.09      1.10      0.03            0.04            0.15                1.04                1.16
#
#          z      p  -log2(p)
# fin  -1.98   0.05      4.39
# age  -2.62   0.01      6.83
# wexp -0.67   0.50      0.99
# mar  -1.15   0.25      2.00
# paro -0.44   0.66      0.60
# prio  3.21 <0.005      9.56
# ---
# Concordance = 0.63
# Log-likelihood ratio test = 32.73 on 6 df, -log2(p)=16.37

# %%
from lifelines import CoxPHFitter

df = pd.DataFrame({
    'T': [5, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
    'E': [1, 1, 1, 1, 1, 1, 0, 0, 1, 1, 1, 0],
    'weights': [1.1, 0.5, 2.0, 1.6, 1.2, 4.3, 1.4, 4.5, 3.0, 3.2, 0.4, 6.2],
    'month': [10, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
    'age': [4, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
})

cph = CoxPHFitter()
cph.fit(df, 'T', 'E', weights_col='weights', robust=True)
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 12 observations, 3 censored>
#       duration col = 'T'
#          event col = 'E'
#        weights col = 'weights'
#    robust variance = True
# number of subjects = 12
#   number of events = 9
# partial log-likelihood = -20.54
#   time fit was run = 2019-08-20 12:45:03 UTC
#
# ---
#         coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# month  -3.34      0.04      0.12           -3.58           -3.09                0.03                0.05
# age   -16.68      0.00      0.22          -17.11          -16.24                0.00                0.00
#
#            z      p  -log2(p)
# month -26.90 <0.005    526.87
# age   -75.16 <0.005       inf
# ---
# Concordance = 0.97
# Log-likelihood ratio test = 46.45 on 2 df, -log2(p)=33.50
# C:\Users\JinMH\Anaconda3\envs\keras\lib\site-packages\lifelines\utils\__init__.py:987: ConvergenceWarning: Column age has high sample correlation with the duration column. This may harm convergence. This could be a form of 'complete separation'.     See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression
#   warnings.warn(dedent(warning_text), ConvergenceWarning)
# C:\Users\JinMH\Anaconda3\envs\keras\lib\site-packages\lifelines\fitters\coxph_fitter.py:568: ConvergenceWarning: Newton-Rhaphson convergence completed but norm(delta) is still high, 1.890. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
#   ConvergenceWarning,

# %%
df
# Out:
#     T  E  weights  month  age
# 0   5  1      1.1     10    4
# 1   3  1      0.5      3    3
# 2   9  1      2.0      9    9
# 3   8  1      1.6      8    8
# 4   7  1      1.2      7    7
# 5   4  1      4.3      4    4
# 6   4  0      1.4      4    4
# 7   3  0      4.5      3    3
# 8   2  1      3.0      2    2
# 9   5  1      3.2      5    5
# 10  6  1      0.4      6    6
# 11  7  0      6.2      7    7

# %%
from lifelines import CoxPHFitter

df = pd.DataFrame({
    'T': [5, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
    'E': [1, 1, 1, 1, 1, 1, 0, 0, 1, 1, 1, 0],
    'month': [10, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
    'age': [4, 3, 9, 8, 7, 4, 4, 3, 2, 5, 6, 7],
    'id': [1, 1, 1, 1, 2, 3, 3, 4, 4, 5, 6, 7]
})

cph = CoxPHFitter()
cph.fit(df, 'T', 'E', cluster_col='id')
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 12 observations, 3 censored>
#       duration col = 'T'
#          event col = 'E'
#        cluster col = 'id'
#    robust variance = True
# number of subjects = 12
#   number of events = 9
# partial log-likelihood = -2.77
#   time fit was run = 2019-08-20 12:45:23 UTC
#
# ---
#         coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# month  -3.08      0.05      0.10           -3.27           -2.89                0.04                0.06
# age   -15.40      0.00      0.30          -15.98          -14.82                0.00                0.00
#
#            z      p  -log2(p)
# month -31.09 <0.005    702.62
# age   -51.99 <0.005       inf
# ---
# Concordance = 0.97
# Log-likelihood ratio test = 23.47 on 2 df, -log2(p)=16.93
# C:\Users\JinMH\Anaconda3\envs\keras\lib\site-packages\lifelines\utils\__init__.py:987: ConvergenceWarning: Column age has high sample correlation with the duration column. This may harm convergence. This could be a form of 'complete separation'.     See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression
#   warnings.warn(dedent(warning_text), ConvergenceWarning)
# C:\Users\JinMH\Anaconda3\envs\keras\lib\site-packages\lifelines\fitters\coxph_fitter.py:568: ConvergenceWarning: Newton-Rhaphson convergence completed but norm(delta) is still high, 1.890. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
#   ConvergenceWarning,

# %% [markdown]
# # The Weibull AFT model

# %%
from lifelines import WeibullAFTFitter
from lifelines.datasets import load_rossi

rossi_dataset = load_rossi()

aft = WeibullAFTFitter()
aft.fit(rossi_dataset, duration_col='week', event_col='arrest')

aft.print_summary(3)  # access the results using aft.summary
# Out:
# <lifelines.WeibullAFTFitter: fitted with 432 observations, 318 censored>
#          event col = 'arrest'
# number of subjects = 432
#   number of events = 114
#     log-likelihood = -679.917
#   time fit was run = 2019-08-20 12:45:50 UTC
#
# ---
#                      coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# lambda_ fin         0.272     1.313     0.138           0.002           0.543               1.002               1.720
#         age         0.041     1.042     0.016           0.009           0.072               1.009               1.075
#         race       -0.225     0.799     0.220          -0.656           0.207               0.519               1.230
#         wexp        0.107     1.112     0.152          -0.190           0.404               0.827               1.497
#         mar         0.311     1.365     0.273          -0.224           0.847               0.799               2.332
#         paro        0.059     1.061     0.140          -0.215           0.333               0.807               1.394
#         prio       -0.066     0.936     0.021          -0.107          -0.025               0.899               0.976
#         _intercept  3.990    54.061     0.419           3.169           4.812              23.776             122.921
# rho_    _intercept  0.339     1.404     0.089           0.165           0.514               1.179               1.671
#
#                         z       p  -log2(p)
# lambda_ fin         1.973   0.049     4.365
#         age         2.544   0.011     6.512
#         race       -1.021   0.307     1.703
#         wexp        0.703   0.482     1.053
#         mar         1.139   0.255     1.972
#         paro        0.421   0.674     0.570
#         prio       -3.143   0.002     9.224
#         _intercept  9.521 <0.0005    68.976
# rho_    _intercept  3.809 <0.0005    12.807
# ---
# Concordance = 0.640
# Log-likelihood ratio test = 33.416 on 7 df, -log2(p)=15.462

# %%
rossi_dataset.head()
# Out:
#    week  arrest  fin  age  race  wexp  mar  paro  prio
# 0    20       1    0   27     1     0    0     1     3
# 1    17       1    0   18     1     0    0     1     8
# 2    25       1    0   19     0     1    0     1    13
# 3    52       0    1   23     1     1    1     1     1
# 4    52       0    0   19     0     1    0     1     3

# %%
print(aft.median_survival_time_)
print(aft.mean_survival_time_)
# Out:
# 100.32670070855555
# 118.67416351029551

# %%
aft = WeibullAFTFitter()

aft.fit(rossi, duration_col='week', event_col='arrest', ancillary_df=False)
# identical to aft.fit(rossi, duration_col='week', event_col='arrest', ancillary_df=None)


aft.fit(rossi, duration_col='week', event_col='arrest', ancillary_df=rossi)


aft.fit(rossi, duration_col='week', event_col='arrest', ancillary_df=True)
# identical to aft.fit(rossi, duration_col='week', event_col='arrest', ancillary_df=rossi)

aft.print_summary()
# Out:
# <lifelines.WeibullAFTFitter: fitted with 432 observations, 318 censored>
#          event col = 'arrest'
# number of subjects = 432
#   number of events = 114
#     log-likelihood = -669.40
#   time fit was run = 2019-08-20 12:47:14 UTC
#
# ---
#                     coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# lambda_ fin         0.24      1.28      0.15           -0.06            0.55                0.95                1.73
#         age         0.10      1.10      0.03            0.04            0.16                1.04                1.17
#         race        0.07      1.07      0.19           -0.30            0.44                0.74                1.55
#         wexp       -0.34      0.71      0.15           -0.64           -0.04                0.53                0.96
#         mar         0.26      1.30      0.30           -0.33            0.85                0.72                2.35
#         paro        0.09      1.10      0.15           -0.21            0.39                0.81                1.48
#         prio       -0.08      0.92      0.02           -0.12           -0.04                0.89                0.96
#         _intercept  2.68     14.65      0.60            1.51            3.85                4.55               47.22
# rho_    fin        -0.01      0.99      0.15           -0.31            0.29                0.73                1.33
#         age        -0.05      0.95      0.02           -0.08           -0.02                0.93                0.98
#         race       -0.46      0.63      0.25           -0.95            0.04                0.39                1.04
#         wexp        0.56      1.74      0.17            0.23            0.88                1.26                2.42
#         mar         0.10      1.10      0.27           -0.44            0.63                0.65                1.87
#         paro        0.02      1.02      0.16           -0.29            0.33                0.75                1.39
#         prio        0.03      1.03      0.02           -0.01            0.08                0.99                1.08
#         _intercept  1.48      4.41      0.41            0.68            2.29                1.97                9.89
#
#                        z      p  -log2(p)
# lambda_ fin         1.60   0.11      3.18
#         age         3.43 <0.005     10.69
#         race        0.36   0.72      0.48
#         wexp       -2.22   0.03      5.26
#         mar         0.86   0.39      1.35
#         paro        0.61   0.54      0.88
#         prio       -4.24 <0.005     15.46
#         _intercept  4.50 <0.005     17.14
# rho_    fin        -0.09   0.92      0.11
#         age        -3.10 <0.005      9.01
#         race       -1.79   0.07      3.77
#         wexp        3.32 <0.005     10.13
#         mar         0.36   0.72      0.47
#         paro        0.12   0.90      0.15
#         prio        1.44   0.15      2.73
#         _intercept  3.60 <0.005     11.62
# ---
# Concordance = 0.63
# Log-likelihood ratio test = 54.45 on 14 df, -log2(p)=19.83

# %%
wft = WeibullAFTFitter().fit(rossi, 'week', 'arrest', ancillary_df=True)
wft.plot()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

times = np.arange(0, 100)
wft_model_rho = WeibullAFTFitter().fit(rossi, 'week', 'arrest', ancillary_df=True, timeline=times)
wft_model_rho.plot_covariate_groups('prio', range(0, 16, 3), cmap='coolwarm', ax=ax[0])
ax[0].set_title("Modelling rho_")

wft_not_model_rho = WeibullAFTFitter().fit(rossi, 'week', 'arrest', ancillary_df=False, timeline=times)
wft_not_model_rho.plot_covariate_groups('prio', range(0, 16, 3), cmap='coolwarm', ax=ax[1])
ax[1].set_title("Not modelling rho_");

# %%
X = rossi.loc[:10]

print(aft.predict_cumulative_hazard(X, ancillary_df=X))
print(aft.predict_survival_function(X, ancillary_df=X))
print(aft.predict_median(X, ancillary_df=X))
print(aft.predict_percentile(X, p=0.9, ancillary_df=X))
print(aft.predict_expectation(X, ancillary_df=X))
# Out:
#             0         1             2         3             4         5   \
# 1.0   0.009571  0.001719  8.913352e-08  0.000056  5.490845e-07  0.000426
# 16.0  0.984393  0.973376  0.876953  0.955016  0.914617
# 17.0  0.982741  0.969856  0.868220  0.949698  0.910004
# 18.0  0.981024  0.966120  0.859466  0.944126  0.905438
# 19.0  0.979245  0.962169  0.850699  0.938307  0.900918
# 20.0  0.977405  0.958005  0.841924  0.932248  0.896441
# 21.0  0.975506  0.953630  0.833148  0.925955  0.892008
# 22.0  0.973548  0.949046  0.824375  0.919436  0.887615
# 23.0  0.971534  0.944256  0.815612  0.912696  0.883262
# 24.0  0.969465  0.939262  0.806862  0.905743  0.878947
# 25.0  0.967340  0.934067  0.798129  0.898584  0.874669
# 26.0  0.965163  0.928673  0.789418  0.891225  0.870428
# 27.0  0.962934  0.923084  0.780733  0.883674  0.866222
# 28.0  0.960653  0.917304  0.772075  0.875937  0.862050
# 30.0  0.955943  0.905181  0.754857  0.859934  0.853807
# 31.0  0.953516  0.898845  0.746301  0.851683  0.849733
# 32.0  0.951041  0.892333  0.737786  0.843274  0.845691
# 33.0  0.948521  0.885646  0.729311  0.834715  0.841679
# 34.0  0.945955  0.878791  0.720881  0.826013  0.837698
# 35.0  0.943346  0.871770  0.712496  0.817174  0.833746
# 36.0  0.940692  0.864589  0.704159  0.808206  0.829822
# 37.0  0.937997  0.857251  0.695871  0.799116  0.825927
# 38.0  0.935259  0.849761  0.687634  0.789912  0.822060
# 39.0  0.932481  0.842124  0.679449  0.780599  0.818220
# 40.0  0.929663  0.834345  0.671318  0.771185  0.814407
# 42.0  0.923911  0.818378  0.655222  0.752081  0.806859
# 43.0  0.920977  0.810200  0.647259  0.742405  0.803123
# 44.0  0.918007  0.801900  0.639354  0.732655  0.799413
# 45.0  0.915001  0.793482  0.631509  0.722839  0.795728
# 46.0  0.911960  0.784952  0.623723  0.712962  0.792066
# 47.0  0.908884  0.776315  0.615998  0.703031  0.788429
# 48.0  0.905775  0.767575  0.608335  0.693052  0.784816
# 49.0  0.902632  0.758739  0.600733  0.683033  0.781226
# 50.0  0.899456  0.749811  0.593195  0.672980  0.777659
# 52.0  0.893011  0.731703  0.578308  0.652793  0.770592
#              0
# 0   130.125208
# 1    42.520219
# 2    24.214888
# 3   151.607484
# 4    53.418859
# 5    82.856469
# 6   153.529064
# 7    76.313167
# 8    63.161353
# 9    67.245207
# 10  152.523053
#             0
# 0   15.285003
# 1   13.097926
# 2   16.586296
# 3   55.586550
# 4   31.334073
# 5   26.888414
# 6   49.829517
# 7   30.819828
# 8   13.342135
# 9   24.804422
# 10  19.204200
#              0
# 0   210.373095
# 1    47.937976
# 2    23.925940
# 3   163.596314
# 4    53.345212
# 5    92.125151
# 6   170.697622
# 7    80.636024
# 8    80.201633
# 9    72.462658
# 10  238.863842

# %%
churn_data = pd.read_csv(
    'https://raw.githubusercontent.com/treselle-systems/'
    'customer_churn_analysis/master/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
churn_data.shape
# Out:
# (7043, 21)

# %%
churn_data.customerID.nunique()
# Out:
# 7043
